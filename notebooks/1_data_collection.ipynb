# %%
import requests
from bs4 import BeautifulSoup
import re
import dill
import json
import datetime

# %% [markdown]
# # Web Crawler for Epicurious

# %% [markdown]
# ## 1. get all the links of recipes and write them into "data/epi-links.pkd"

# %%
search_result_pages = ["https://www.epicurious.com/search/?content=recipe&page=" + str(i) for i in range(1,1970)]

# %%
def get_url_title(el):
    try:
        url = re.search(r'<a.+href="(.+)">(.+[\s\S]+)<\/a>', str(el)).group(1)
        title = re.search(r'<a.+href="(.+)">(.+[\s\S]+)<\/a>', str(el)).group(2).strip()
        #text = requests.get(""+url).text
        return (title, url)
    except:
        print(el)
        return None

def get_recipe_links(page):
    recipe_links = []
    soup = BeautifulSoup(page.text,'lxml')
    els = soup.select('article.recipe-content-card h4 a')
    return [get_url_title(el) for el in els]

# %%
from requests_futures.sessions import FuturesSession

session = FuturesSession(max_workers=5)

links = [link
        for future in [session.get(page) for page in search_result_pages]
        for link in get_recipe_links(future.result())]

# %%
#len(links)
# Out:
# 35441

# %%
#links[0]
# Out:
# ('Chicken Salad with Apricots, Celery, and Blue Cheese',
#  '/recipes/food/views/chicken-salad-with-apricots-celery-and-blue-cheese')

# %%
#dill.dump(links, open('../data/epi-links.pkd', 'wb'))

# %%
link_list = dill.load(open('../data/epi-links.pkd', 'rb'))
len(link_list)
# Out:
# 35441

# %%
link_list[-1]
# Out:
# ('Portobello Mushroom Salad à la Grecque',
#  '/recipes/food/views/portobello-mushroom-salad-a-la-grecque-recipe')

# %% [markdown]
# ## 2. get all the recipes and write them into "data/epi-recipes.json"

# %%
## require requests, BeautifulSoup, re, json
class Recipe:

################################################################################################ init empty recipe
    def __init__(self):

        self.title = ''
        self.url = ''
        self.imgurl = ''
        self.desc = ''

        self.ingredients = []
        self.steps = []
        self.tags = []
        self.nutritions = {}
        self.serving = 0

        self.yiel = ''
        self.activetime = ''
        self.totaltime = ''

        self.rating = 0
        self.reviewcount = 0
        self.makeagain = 0
        self.reviews = []


############################################################################ init recipe using a recipe detial page
    def __init__(self, path):

        self.url = "https://www.epicurious.com" + path
        page = requests.get(self.url)
        soup = BeautifulSoup(page.text, 'lxml')

        self.title = self.build_title(soup)
        self.imgurl = self.build_imgurl(soup)
        self.desc = self.build_desc(soup)

        self.ingredients = self.build_ingredients(soup)
        self.steps = self.build_steps(soup)
        self.tags = self.build_tags(soup)
        self.nutritions = self.build_nutritions(soup)
        self.serving = self.build_serving(soup)

        self.yiel = self.build_yield(soup)
        self.activetime = self.build_activetime(soup)
        self.totaltime = self.build_totaltime(soup)

        self.rating = self.build_rating(soup)
        self.reviewcount = self.build_reviewcount(soup)
        self.makeagain = self.build_makeagain(soup)
        self.reviews = self.build_reviews(soup)


########################################################################### fuctions: get infomation from a page
    def build_title(self, soup):
        try:
            el = soup.select('div.main-content div.title-source h1')
            title = re.search(r'\">(.+)<', str(el)).group(1).strip()
            return title
        except:
            print("Title Wrong: "+self.url)
            return ''

    def build_imgurl(self, soup):
        try:
            el = soup.select('div.main-content img["srcset"]')
            imgurl = re.search(r'srcset="(.+)"\/>', str(el)).group(1)
            return imgurl
        except:
            #print("IMG Wrong: "+self.url)
            return ''

    def build_desc(self, soup):
        try:
            el = soup.select('div.main-content div.dek')
            desc = re.search(r'<p>(.+)<\/p>', str(el)).group(1).strip()
            return desc
        except:
            #print("Desc Wrong: "+self.url)
            return ''


    def build_ingredients(self, soup):
        try:
            ingredients = []
            els = soup.select('div.main-content div.ingredients-info li.ingredient')
            for el in els:
                ingredients.append(re.search(r'<li.+>(\s*.+\s*)<\/li>', str(el)).group(1).strip())
            return ingredients
        except:
            print("Ingredients Wrong: "+self.url)
            return []

    def build_steps(self, soup):
        try:
            steps = []
            els = soup.select('div.main-content div.instructions li.preparation-step')
            for el in els:
                steps.append(re.search(r'<li.+>(\s*.+\s*)<\/li>', str(el)).group(1).strip())
            return steps
        except:
            print("Steps Wrong: "+self.url)
            return []

    def build_tags(self, soup):
        try:
            tags = []
            els = soup.select('div.main-content dl.tags a')
            for el in els:
                tags.append(re.search(r'\".+>(.+)<\/dt>', str(el)).group(1))
            return tags
        except:
            print("Tags Wrong: "+self.url)
            return []

    def build_nutritions(self, soup):
        try:
            nutritions = {}
            labels = soup.select('div.main-content span.nutri-label')
            values = soup.select('div.main-content span.nutri-data')
            for i in range(len(labels)):
                n = re.search(r'\">(.+)<\/', str(labels[i])).group(1)
                v = re.search(r'\">(.+)<\/', str(values[i])).group(1)
                v = float(v.split(' ')[0])
                nutritions[n] = v
            return nutritions
        except:
            #print("Nutritions Wrong: "+self.url)
            return {}

    def build_serving(self, soup):
        try:
            el = soup.select('div.main-content span.per-serving')
            serving = re.search(r'.+(\d+).+',str(el)).group(1)
            return float(serving)
        except:
            #print("Serving Wrong: "+self.url)
            return 0


    def build_yield(self, soup):
        try:
            el = soup.select('div.main-content dd.yield')
            y = re.search(r'\">(.+)<', str(el)).group(1)
            return y
        except:
            #print("Yield Wrong: "+self.url)
            return ''

    def build_activetime(self, soup):
        try:
            el = soup.select('div.main-content dd.active-time')
            active = re.search(r'\">(.+)<', str(el)).group(1)
            return active
        except:
            #print("Activetime Wrong: "+self.url)
            return ''

    def build_totaltime(self, soup):
        try:
            el = soup.select('div.main-content dd.total-time')
            total = re.search(r'\">(.+)<', str(el)).group(1)
            return total
        except:
            #print("Totaltime Wrong: "+self.url)
            return ''


    def build_rating(self, soup):
        try:
            el = soup.select('div.main-content span.rating')
            rating = re.search(r'\">(.+)\/\d', str(el)).group(1)
            return float(rating)
        except:
            print("Rating Wrong: "+self.url)
            return 0

    def build_reviewcount(self, soup):
        try:
            el = soup.select('div.main-content span.reviews-count')
            reviewcount = re.search(r'(\d+)', str(el)).group(1)
            return float(reviewcount)
        except:
            print("Reviewcount Wrong: "+self.url)
            return 0

    def build_makeagain(self, soup):
        try:
            el = soup.select('div.main-content div.prepare-again-rating span')
            makeagain = re.search(r'(\d+)', str(el)).group(1)
            return float(makeagain)
        except:
            print("MakeagainRating Wrong: "+self.url)
            return 0

    def build_reviews(self, soup):
        try:
            reviews = []
            els = soup.select('div.main-content div.reviews li div.review-text p')
            for el in els:
                review = re.search(r'\">(.+[\s\S]*)<', str(r)).group(1).strip()
                reviews.append(review)
            return reviews
        except:
            #print("Reviews Wrong: "+self.url)
            return []


######################################################################################################### to string
    def __str__(self):
        string = "\nTitle: " + self.title + "\nURL: " + self.url + "\nIMG URL: " + self.imgurl + "\nDesc: " + self.desc + "\nIngredients: " + str(self.ingredients) + "\nSteps: " + str(self.steps) + "\nTags: " + str(self.tags) + "\nNutritions: " + str(self.nutritions) + "\nServing: " + str(self.serving) + "\nYield: " + self.yiel + "\nActive time: " + self.activetime + "\nTotal time: " + self.totaltime + "\nRating: " + str(self.rating) + "\nReview count: " + str(self.reviewcount) + "\nMake again: " + str(self.makeagain) + "\nReviews: " + str(self.reviews)
        return string

######################################################################################################### getters
    def get_title(self):
        return self.title

    def get_url(self):
        return self.url

    def get_imgurl(self):
        return self.imgurl

    def get_desc(self):
        return self.desc


    def get_ingredients(self):
        return self.ingredients

    def get_steps(self):
        return self.steps

    def get_tags(self):
        return self.tags

    def get_nutritions(self):
        return self.nutritions

    def get_serving(self):
        return self.serving


    def get_yield(self):
        return self.yiel

    def get_activetime(self):
        return self.activetime

    def get_totaltime(self):
        return self.totaltime


    def get_rating(self):
        return self.rating

    def get_reviewcount(self):
        return self.reviewcount

    def get_makeagain(self):
        return self.makeagain

    def get_reviews(self):
        return self.reviews

# %%
recipes = []
count = 1


for link in link_list:
    count += 1
    recipes.append(Recipe(link[1]))
    if count%5000 == 0:
        print("Finish %d pages at "%count + str(datetime.datetime.today()))
# Out:
# Steps Wrong: https://www.epicurious.com/recipes/food/views/sams-spring-cucumber-radish-fattoush-salad
# Steps Wrong: https://www.epicurious.com/recipes/food/views/vietnamese-candy-pork
# Steps Wrong: https://www.epicurious.com/recipes/food/views/salted-caramel-chocolate-tart
# Steps Wrong: https://www.epicurious.com/recipes/food/views/spicy-dry-fried-beef
# Steps Wrong: https://www.epicurious.com/recipes/food/views/spinach-yogurt-dip-with-sizzled-mint
# Steps Wrong: https://www.epicurious.com/recipes/food/views/perfect-pot-roast
# Steps Wrong: https://www.epicurious.com/recipes/food/views/roasted-acorn-squash-with-sage-and-honey
# Steps Wrong: https://www.epicurious.com/recipes/food/views/paella-with-tomatoes-and-eggs
# Steps Wrong: https://www.epicurious.com/recipes/food/views/muffin-cup-vegetarian-veggie-omelets
# Steps Wrong: https://www.epicurious.com/recipes/food/views/pan-roasted-chicken-with-shallots-and-dates
# Steps Wrong: https://www.epicurious.com/recipes/food/views/blood-orange-poppy-polenta-shortbread-cookies
# Steps Wrong: https://www.epicurious.com/recipes/food/views/filipino-style-meatloaf-embutido
# Steps Wrong: https://www.epicurious.com/recipes/food/views/frosted-malt-chocolate-cookies
# Steps Wrong: https://www.epicurious.com/recipes/food/views/buttery-pull-apart-dinner-rolls
# Steps Wrong: https://www.epicurious.com/recipes/food/views/gujarti-eggplant-and-sweet-potato-lasagna-with-kadi-sauce
# Steps Wrong: https://www.epicurious.com/recipes/food/views/cheesy-potato-and-kale-gratin-with-rye-croutons
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/kale-dusted-pecorino-popcorn
# Steps Wrong: https://www.epicurious.com/recipes/food/views/eggs-benedict-with-asparagus-and-brie
# Steps Wrong: https://www.epicurious.com/recipes/food/views/indian-style-butter-chicken-curry
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chop-chop-salad
# Steps Wrong: https://www.epicurious.com/recipes/food/views/simple-one-skillet-chicken-alfredo-pasta
# Steps Wrong: https://www.epicurious.com/recipes/food/views/breakfast-pizza-with-sausage-eggs-spinach-and-cream
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chilled-ramen-with-soy-milk-and-chili-oil
# Steps Wrong: https://www.epicurious.com/recipes/food/views/lemon-ice
# Steps Wrong: https://www.epicurious.com/recipes/food/views/traditional-sauerkraut-with-caraway
# Steps Wrong: https://www.epicurious.com/recipes/food/views/vegan-nicoise-style-salad
# Steps Wrong: https://www.epicurious.com/recipes/food/views/homemade-baked-tofu
# Steps Wrong: https://www.epicurious.com/recipes/food/views/spice-rubbed-pork-tenderloin-with-a-mediterranean-grain-salad
# Steps Wrong: https://www.epicurious.com/recipes/food/views/mango-chutney-chicken-with-roasted-carrots-and-zucchini
# Steps Wrong: https://www.epicurious.com/recipes/food/views/coco-lopez-coconut-cake
# Steps Wrong: https://www.epicurious.com/recipes/food/views/cold-fry-frites
# Steps Wrong: https://www.epicurious.com/recipes/food/views/instant-pot-italian-chickpea-stew-with-pesto
# Steps Wrong: https://www.epicurious.com/recipes/food/views/pulled-flank-steak-in-red-wine-sauce-ropa-vieja-o-carne-ripiada
# Steps Wrong: https://www.epicurious.com/recipes/food/views/mushroom-thyme-pot-pies
# Steps Wrong: https://www.epicurious.com/recipes/food/views/espresso-chocolate-sables
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/slow-cooker-macaroni-and-cheese
# Steps Wrong: https://www.epicurious.com/recipes/food/views/medianoche-midnight-sandwich
# Steps Wrong: https://www.epicurious.com/recipes/food/views/mojo-criollo
# Steps Wrong: https://www.epicurious.com/recipes/food/views/lechon-asado
# Steps Wrong: https://www.epicurious.com/recipes/food/views/carolina-style-pork-bbq-sandwiches
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/chinese-rice-cakes-with-greens-bamboo-shoots-and-soybeans
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/yogurt-tartar-sauce
# Steps Wrong: https://www.epicurious.com/recipes/food/views/mashed-yam-and-plantain
# Steps Wrong: https://www.epicurious.com/recipes/food/views/kiwi-ice-pop
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/african-jollof-rice
# Steps Wrong: https://www.epicurious.com/recipes/food/views/gluten-free-blueberry-and-cinnamon-breakfast-oat-muffins
# Steps Wrong: https://www.epicurious.com/recipes/food/views/smoked-salmon-quiche-with-kale-and-basil-and-sesame-seed-crust
# Steps Wrong: https://www.epicurious.com/recipes/food/views/feta-spinach-and-basil-omelette-muffins
# Steps Wrong: https://www.epicurious.com/recipes/food/views/fruity-berry-tarts-with-vanilla-cashew-cream
# Steps Wrong: https://www.epicurious.com/recipes/food/views/quinoa-mushroom-frittata-with-fresh-herbs
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/garlic-herb-naan
# Steps Wrong: https://www.epicurious.com/recipes/food/views/grilled-escarole
# Steps Wrong: https://www.epicurious.com/recipes/food/views/maple-syrup-candies
# Steps Wrong: https://www.epicurious.com/recipes/food/views/cornbread-stuffed-roasted-squash
# Title Wrong: https://www.epicurious.com/recipes/food/views/chocolate-plum-cake56390135
# Rating Wrong: https://www.epicurious.com/recipes/food/views/chocolate-plum-cake56390135
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/chocolate-plum-cake56390135
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/chocolate-plum-cake56390135
# Title Wrong: https://www.epicurious.com/suzanne-goin-s-corned-beef-and-cabbage-with-parsley-mustard-sauce-56389323-recipe
# Rating Wrong: https://www.epicurious.com/suzanne-goin-s-corned-beef-and-cabbage-with-parsley-mustard-sauce-56389323-recipe
# Reviewcount Wrong: https://www.epicurious.com/suzanne-goin-s-corned-beef-and-cabbage-with-parsley-mustard-sauce-56389323-recipe
# MakeagainRating Wrong: https://www.epicurious.com/suzanne-goin-s-corned-beef-and-cabbage-with-parsley-mustard-sauce-56389323-recipe
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chicken-with-lemons-and-olives-emshmel-231572
# Steps Wrong: https://www.epicurious.com/recipes/food/views/steamed-lamb-231571
# Steps Wrong: https://www.epicurious.com/recipes/food/views/preserved-lemons-231570
# Title Wrong: https://www.epicurious.com/recipes/food/views/to-peel-plantains-105639
# Rating Wrong: https://www.epicurious.com/recipes/food/views/to-peel-plantains-105639
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/to-peel-plantains-105639
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/to-peel-plantains-105639
# Title Wrong: https://www.epicurious.com/recipes/food/views/to-wash-greens-and-chopped-sliced-leeks-241804
# Rating Wrong: https://www.epicurious.com/recipes/food/views/to-wash-greens-and-chopped-sliced-leeks-241804
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/to-wash-greens-and-chopped-sliced-leeks-241804
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/to-wash-greens-and-chopped-sliced-leeks-241804
# Title Wrong: https://www.epicurious.com/simple-syrup-368889-recipe
# Rating Wrong: https://www.epicurious.com/simple-syrup-368889-recipe
# Reviewcount Wrong: https://www.epicurious.com/simple-syrup-368889-recipe
# MakeagainRating Wrong: https://www.epicurious.com/simple-syrup-368889-recipe
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/seafood-chowder-with-bacon-and-thyme-51254410
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chicken-andouille-gumbo-51252530
# Title Wrong: https://www.epicurious.com/recipes/seared-scallops-with-tomato-water-lime-and-mint-51242060-recipe
# Rating Wrong: https://www.epicurious.com/recipes/seared-scallops-with-tomato-water-lime-and-mint-51242060-recipe
# Reviewcount Wrong: https://www.epicurious.com/recipes/seared-scallops-with-tomato-water-lime-and-mint-51242060-recipe
# MakeagainRating Wrong: https://www.epicurious.com/recipes/seared-scallops-with-tomato-water-lime-and-mint-51242060-recipe
# Title Wrong: https://www.epicurious.com/recipes/food/views/salmon-cakes-with-arugula-salad-51240450
# Rating Wrong: https://www.epicurious.com/recipes/food/views/roasted-salmon-with-potatoes-and-herbed-creme-fraiche-51236440
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/roasted-salmon-with-potatoes-and-herbed-creme-fraiche-51236440
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/roasted-salmon-with-potatoes-and-herbed-creme-fraiche-51236440
# Rating Wrong: https://www.epicurious.com/recipes/food/views/chicken-salad-with-creme-fraiche-and-rye-51236450
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/chicken-salad-with-creme-fraiche-and-rye-51236450
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/chicken-salad-with-creme-fraiche-and-rye-51236450
# Rating Wrong: https://www.epicurious.com/recipes/food/views/sesame-rice-noodles-with-shrimp-51235820
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/sesame-rice-noodles-with-shrimp-51235820
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/sesame-rice-noodles-with-shrimp-51235820
# Rating Wrong: https://www.epicurious.com/recipes/food/views/linguine-and-clams-with-almonds-and-herbs-51231650
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/linguine-and-clams-with-almonds-and-herbs-51231650
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/linguine-and-clams-with-almonds-and-herbs-51231650
# Steps Wrong: https://www.epicurious.com/recipes/food/views/tempering-chocolate-51228820
# Rating Wrong: https://www.epicurious.com/recipes/food/views/almond-pistachio-nougatine-51228610
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/almond-pistachio-nougatine-51228610
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/almond-pistachio-nougatine-51228610
# Steps Wrong: https://www.epicurious.com/recipes/food/views/hot-toddy-51213610
# Steps Wrong: https://www.epicurious.com/recipes/food/views/ghetto-pillsbury-fried-doughnuts-51210810
# Steps Wrong: https://www.epicurious.com/recipes/food/views/basic-clafoutis-51208430
# Steps Wrong: https://www.epicurious.com/recipes/food/views/garden-greens-and-goat-cheese-pasta-51207410
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chickpea-and-broccoli-rabe-soup-51207210
# Steps Wrong: https://www.epicurious.com/recipes/food/views/pie-dough-51207230
# Steps Wrong: https://www.epicurious.com/recipes/food/views/sierra-beauty-apple-pie-51207220
# Rating Wrong: https://www.epicurious.com/recipes/food/views/easy-does-it-baby-51205650
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/easy-does-it-baby-51205650
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/easy-does-it-baby-51205650
# Rating Wrong: https://www.epicurious.com/recipes/food/views/sea-bean-salad-with-daikon-and-cucumber-51199610
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/sea-bean-salad-with-daikon-and-cucumber-51199610
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/sea-bean-salad-with-daikon-and-cucumber-51199610
# Steps Wrong: https://www.epicurious.com/recipes/food/views/seasonal-fruit-herb-saladitas-51196810
# Rating Wrong: https://www.epicurious.com/recipes/food/views/tarte-bourdaloue-51194810
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/tarte-bourdaloue-51194810
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/tarte-bourdaloue-51194810
# Steps Wrong: https://www.epicurious.com/recipes/food/views/eggplant-parmesan-with-fresh-mozzarella-51193670
# Steps Wrong: https://www.epicurious.com/recipes/food/views/lemonade-jelly-with-basil-51176800
# Steps Wrong: https://www.epicurious.com/recipes/food/views/pickled-swiss-chard-stems-51175630
# Steps Wrong: https://www.epicurious.com/recipes/food/views/master-buttermilk-brine-51175370
# Rating Wrong: https://www.epicurious.com/recipes/food/views/chicken-tikka-masala-51171400
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/chicken-tikka-masala-51171400
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/chicken-tikka-masala-51171400
# Steps Wrong: https://www.epicurious.com/recipes/food/views/fish-brine-51170430
# Rating Wrong: https://www.epicurious.com/recipes/food/views/asian-chicken-and-cabbage-salad-51160620
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/asian-chicken-and-cabbage-salad-51160620
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/asian-chicken-and-cabbage-salad-51160620
# Finish 5000 pages at 2018-06-25 23:53:18.730472
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/braised-chicken-with-artichokes-and-olives-51150800
# Rating Wrong: https://www.epicurious.com/recipes/food/views/sichuanese-wontons-in-chilli-oil-sauce-em-hong-you-chao-shou-em-51147600
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/sichuanese-wontons-in-chilli-oil-sauce-em-hong-you-chao-shou-em-51147600
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/sichuanese-wontons-in-chilli-oil-sauce-em-hong-you-chao-shou-em-51147600
# Rating Wrong: https://www.epicurious.com/recipes/food/views/classic-chocolate-mousse-51143870
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/classic-chocolate-mousse-51143870
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/classic-chocolate-mousse-51143870
# Rating Wrong: https://www.epicurious.com/recipes/food/views/spicy-summer-rolls-with-peanut-dipping-sauce-51137600
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/spicy-summer-rolls-with-peanut-dipping-sauce-51137600
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/spicy-summer-rolls-with-peanut-dipping-sauce-51137600
# Rating Wrong: https://www.epicurious.com/recipes/food/views/mixed-berry-gazpacho-with-basil-51104710
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/mixed-berry-gazpacho-with-basil-51104710
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/mixed-berry-gazpacho-with-basil-51104710
# Steps Wrong: https://www.epicurious.com/recipes/food/views/cast-iron-mac-and-cheese-51100650
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/malted-vanilla-ice-cream-with-peanut-brittle-and-milk-chocolate-pieces-51100020
# Rating Wrong: https://www.epicurious.com/recipes/food/views/seasoned-dhal-em-masala-dhal-em-394654
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/seasoned-dhal-em-masala-dhal-em-394654
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/seasoned-dhal-em-masala-dhal-em-394654
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chicken-wings-five-ways-388449
# Steps Wrong: https://www.epicurious.com/recipes/food/views/yum-yum-nut-sweets-369549
# Title Wrong: https://www.epicurious.com/recipes/food/views/brochette-de-lapin-aux-pruneaux-368960
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/petits-farcis-368949
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/peameal-bacon-368929
# Rating Wrong: https://www.epicurious.com/recipes/food/views/south-indian-lentil-cakes-with-raita-367156
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/south-indian-lentil-cakes-with-raita-367156
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/south-indian-lentil-cakes-with-raita-367156
# Rating Wrong: https://www.epicurious.com/recipes/food/views/peach-prosciutto-ricotta-crostini-365769
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/peach-prosciutto-ricotta-crostini-365769
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/peach-prosciutto-ricotta-crostini-365769
# Steps Wrong: https://www.epicurious.com/recipes/food/views/yaki-onigiri-365589
# Rating Wrong: https://www.epicurious.com/recipes/food/views/paneer-curry-with-peas-358211
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/paneer-curry-with-peas-358211
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/paneer-curry-with-peas-358211
# Steps Wrong: https://www.epicurious.com/recipes/food/views/sticky-balsamic-ribs-354213
# Steps Wrong: https://www.epicurious.com/recipes/food/views/corn-and-tomato-scramble-354230
# Steps Wrong: https://www.epicurious.com/recipes/food/views/lemony-potato-salad-354231
# Steps Wrong: https://www.epicurious.com/recipes/food/views/green-beans-with-sweet-onion-vinaigrette-354192
# Steps Wrong: https://www.epicurious.com/recipes/food/views/eggplant-and-sun-dried-tomato-spread-354212
# Rating Wrong: https://www.epicurious.com/recipes/food/views/salmon-and-cucumber-boats-353109
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/salmon-and-cucumber-boats-353109
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/salmon-and-cucumber-boats-353109
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/bibimbap-352271
# Rating Wrong: https://www.epicurious.com/recipes/food/views/tandoori-chicken-238388
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/tandoori-chicken-238388
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/tandoori-chicken-238388
# Steps Wrong: https://www.epicurious.com/recipes/food/views/50-whole-wheat-sandwich-bread-351231
# Steps Wrong: https://www.epicurious.com/recipes/food/views/basic-soft-white-sandwich-loaf-351269
# Steps Wrong: https://www.epicurious.com/recipes/food/views/golden-dinner-rolls-351232
# Steps Wrong: https://www.epicurious.com/recipes/food/views/rosemary-flat-bread-351249
# Steps Wrong: https://www.epicurious.com/recipes/food/views/basic-brioche-351237
# Steps Wrong: https://www.epicurious.com/recipes/food/views/basic-sourdough-bread-351236
# Finish 10000 pages at 2018-06-26 00:47:42.818190
# Steps Wrong: https://www.epicurious.com/recipes/food/views/grilled-pizza-with-pears-fresh-pecorino-and-walnuts-243004
# Steps Wrong: https://www.epicurious.com/recipes/food/views/creamy-sauerkraut-gratin-with-duck-confit-243547
# Steps Wrong: https://www.epicurious.com/recipes/food/views/espresso-blackberry-macarons-243644
# Steps Wrong: https://www.epicurious.com/recipes/food/views/vietnamese-chicken-salad-243196
# Steps Wrong: https://www.epicurious.com/recipes/food/views/grilled-rainbow-chard-with-fava-beans-and-oregano-242846
# Rating Wrong: https://www.epicurious.com/recipes/food/views/egg-foo-yung-242591
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/egg-foo-yung-242591
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/egg-foo-yung-242591
# Rating Wrong: https://www.epicurious.com/recipes/food/views/classic-cheese-souffle-242119
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/classic-cheese-souffle-242119
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/classic-cheese-souffle-242119
# Rating Wrong: https://www.epicurious.com/recipes/food/views/sesame-balls-with-drunken-fig-filling-241655
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/sesame-balls-with-drunken-fig-filling-241655
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/sesame-balls-with-drunken-fig-filling-241655
# Steps Wrong: https://www.epicurious.com/recipes/food/views/classic-roast-turkey-with-herbed-stuffing-and-old-fashioned-gravy-240444
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/cheese-and-chile-quiche-235751
# Steps Wrong: https://www.epicurious.com/recipes/food/views/lamb-kabab-231920
# Steps Wrong: https://www.epicurious.com/recipes/food/views/moroccan-raw-carrot-salad-231922
# Steps Wrong: https://www.epicurious.com/recipes/food/views/fresh-herb-kuku-231921
# Steps Wrong: https://www.epicurious.com/recipes/food/views/pomegranate-khoresh-231918
# Steps Wrong: https://www.epicurious.com/recipes/food/views/saffron-steamed-plain-basmati-rice-231919
# Steps Wrong: https://www.epicurious.com/recipes/food/views/burekas-my-favorite-breakfast-pastries-231754
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chief-of-staff-cholent-hebronite-hamim-231758
# Steps Wrong: https://www.epicurious.com/recipes/food/views/small-semolina-griddle-breads-231568
# Steps Wrong: https://www.epicurious.com/recipes/food/views/rose-water-syrup-231917
# Finish 15000 pages at 2018-06-26 01:43:18.592518
# Steps Wrong: https://www.epicurious.com/recipes/food/views/gin-gin-mule-232358
# Steps Wrong: https://www.epicurious.com/recipes/food/views/grilled-spice-rubbed-pork-with-tomato-garlic-sauce-232311
# Steps Wrong: https://www.epicurious.com/recipes/food/views/beef-pinwheels-with-arugula-salad-232303
# Steps Wrong: https://www.epicurious.com/recipes/food/views/citrus-blossom-gin-fizz-231861
# Steps Wrong: https://www.epicurious.com/recipes/food/views/chicken-and-frisee-salad-with-roasted-red-peppers-toasted-almonds-and-manchego-231869
# Steps Wrong: https://www.epicurious.com/recipes/food/views/lemon-cheesecake-with-gingersnap-crust-231748
# Steps Wrong: https://www.epicurious.com/recipes/food/views/filipino-style-london-broil-231537
# Finish 20000 pages at 2018-06-26 02:37:59.580427
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/corn-bread-and-spiced-pecan-stuffing-102486
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/english-pudding-with-cranberries-figs-and-brown-sugar-hard-sauce-3021
# Title Wrong: https://www.epicurious.com/recipes/food/views/honey-and-spice-cranberry-sauce-100322
# Rating Wrong: https://www.epicurious.com/recipes/food/views/honey-and-spice-cranberry-sauce-100322
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/honey-and-spice-cranberry-sauce-100322
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/honey-and-spice-cranberry-sauce-100322
# Finish 25000 pages at 2018-06-26 03:35:45.043731
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/baked-apples-105618
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/caramelized-apple-and-pear-pie-102543
# Rating Wrong: https://www.epicurious.com/recipes/food/views/classic-coq-au-vin-107153
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/classic-coq-au-vin-107153
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/classic-coq-au-vin-107153
# Finish 30000 pages at 2018-06-26 04:28:39.370635
# Steps Wrong: https://www.epicurious.com/recipes/food/views/gingerbread-house-103229
# Steps Wrong: https://www.epicurious.com/recipes/food/views/spicy-lemon-marinated-shrimp-102249
# Rating Wrong: https://www.epicurious.com/recipes/food/views/boeuf-bourguignon-102144
# Reviewcount Wrong: https://www.epicurious.com/recipes/food/views/boeuf-bourguignon-102144
# MakeagainRating Wrong: https://www.epicurious.com/recipes/food/views/boeuf-bourguignon-102144
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/chocolate-almond-pie-102544
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/apricot-cranberry-and-walnut-pie-102542
# Steps Wrong: https://www.epicurious.com/recipes/food/views/simply-spiced-shrimp-103748
# Ingredients Wrong: https://www.epicurious.com/recipes/food/views/mashed-potatoes-with-spinach-and-cheese-104725
# Steps Wrong: https://www.epicurious.com/recipes/food/views/lavender-creme-caramel-tart-103337
# Finish 35000 pages at 2018-06-26 05:23:54.042179
# Steps Wrong: https://www.epicurious.com/recipes/food/views/classic-omelette-15068

# %%
len(recipes)
# Out:
# 35441

# %%
dill.dump(recipes, open('../data/epi-recipes.pkd', 'wb'))

# %%
with open('../data/epi-recipes-json.json', 'a') as fp:
    for r in recipes:
        json.dump(r.__dict__, fp)
        fp.write("\n")
